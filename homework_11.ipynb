# %% [markdown]
# **Задание 1**
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
ratings = pd.read_csv('ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
len(data)
# Out:
# 100836

# %%
#ratings[['movieId', 'rating']].head()

# %%
ratings_1 = ratings[ratings['rating'] == 5.0] 
ratings_1.head()
# Out:
#    userId  movieId  rating  timestamp
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 6       1      101     5.0  964980868
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
result = ratings_1['movieId'].value_counts()
result.head()
# Out:
# 318     153
# 296     123
# 356     116
# 2571    109
# 260     104
# Name: movieId, dtype: int64

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.query('movieId == 318').head()
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# **Задание 2**
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data = pd.read_csv('power.csv')
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
len(data)
# Out:
# 100836

# %%
filtered_countries = data[(data['country'] == 'Latvia') | (data['country'] == 'Estonia') | (data['country'] == 'Lithuania')]

filtered_countries.head()
# Out:
#        country  year  quantity  category
# 373  Lithuania  2014      39.0         1
# 374  Lithuania  2013     192.0         1
# 375  Lithuania  2012     196.0         1
# 376  Lithuania  2011     171.0         1
# 377  Lithuania  2010     158.0         1

# %%
data_1 = filtered_countries[(filtered_countries['year'].isin(['2005','2006', '2007', '2008', '2009', '2010'])) & (filtered_countries['category'].isin(['4', '12', '21']))]
print(data_1)
# Out:
#           country  year  quantity  category
# 10617     Estonia  2008       1.0         4
# 10618     Estonia  2007       0.0         4
# 10619     Estonia  2006       0.0         4
# 10620     Estonia  2005       1.0         4
# 11156   Lithuania  2008       1.0         4
# ...           ...   ...       ...       ...
# 253982  Lithuania  2009      98.0        21
# 253983  Lithuania  2008      54.0        21
# 253984  Lithuania  2007      47.0        21
# 253985  Lithuania  2006      31.0        21
# 253986  Lithuania  2005       1.0        21
#
# [411 rows x 4 columns]

# %%
data_1['quantity'].sum()
# Out:
# 240481.0

# %% [markdown]
# **Задание 3**
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
page_url = 'https://fortrader.org/quotes'
df = pd.read_html(page_url, encoding='utf-8')
df[0]
# Out:
#                            Название     Цена  Изменение  Изменение(%)  \
# 0  EURRUB Курс евро к рублю сегодня  78.7724     0.6627        0.8484
# 1       USDRUB Курс рубля к доллару  70.1655     0.4983        0.7153
#
#    Обновлено
# 0        NaN
# 1        NaN

# %%
pd.read_html('https://fortrader.org/quotes')[1]
# Out:
#                            Название    Цена  Изменение  Изменение(%)  \
# 0  Нефть (BRENT) Курс нефти сегодня  41.810       1.43         3.540
# 1   Нефть (WTI) Цены на нефть (WTI)  39.610       1.73         4.570
# 2          Сахар котировки на сахар  12.630      11.47       988.790
# 3                   Газ Цена на газ   1.714       0.13         8.207
#
#    Обновлено
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN

# %%
pd.read_html('https://fortrader.org/quotes')[2]
# Out:
#                       Название       Цена   Изменение Изменение(%)  Обновлено
# 0      Серебро Цена на серебро    17.7790      -0.042       -0.236        NaN
# 1    Палладий Цена на Палладий  1925.3000  нет данных   нет данных        NaN
# 2  Золото Цена золота на бирже  1781.1000        -3.7         -0.2        NaN
# 3      Платина Цены на платину   827.0000       +20.2         +2.5        NaN
# 4      Медь Цена меди на бирже     2.4575     -0.2025      -7.6128        NaN

# %%
pd.read_html('https://fortrader.org/quotes')[3]
# Out:
#                                         Название           Цена  Изменение  \
# 0                                  ВТБ Акции ВТБ       0.035415  +0.000265
# 1                         Газпром Акции газпрома     197.850000      +4.85
# 2                            Лукойл Акции Лукойл    5316.000000       -5.5
# 3                        Роснефть Акции Роснефти     365.450000      -1.60
# 4                       Сбербанк Акции Сбербанка     205.530000      +2.38
# 5           Сургутнефтегаз Акции Сургутнефтегаза      38.450000     +0.150
# 6                      Норникель Акции Норникель   19140.000000       -538
# 7                       Аэрофлот Акции Аерофлота      82.380000      +3.00
# 8                    Северсталь Акции Северсталь     854.200000      +2.60
# 9                    Транснефть Акции Транснефть  139200.000000     +4 650
# 10             Ростелеком Курс акций ростелекома      88.010000      -1.16
# ...
